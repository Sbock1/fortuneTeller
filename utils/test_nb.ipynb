# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
anzahl_Studenten = 10
noten = pd.DataFrame(columns=["Mathe", "Deutsch", "Englisch"])

# %%
def min_max(liste)-> list:
    return [min(liste), max(liste)]

# %%
eine_liste = np.random.randint(1,100, size=10)

# %%
eine_liste
# Out:
# array([41, 25, 88,  2, 81, 12, 48, 98, 98, 57], dtype=int32)

# %%
min_max(eine_liste)
# Out:
# [np.int32(2), np.int32(98)]

# %%
""" This is a message and this comment block can reach through multiple lines.
It is useful for documentation purposes.
"""

message = "Hello World"

# %%
print(message)
# Out:
# Hello World
